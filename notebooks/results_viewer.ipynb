# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../main_results.csv')
df
# Out:
#                         data origin  task name  training split  \
# 0   counterfactually-augmented-data  sentiment            orig
# 1   counterfactually-augmented-data  sentiment            orig
# 2   counterfactually-augmented-data  sentiment            orig
# 3   counterfactually-augmented-data  sentiment            orig
# 4   counterfactually-augmented-data  sentiment             new
# ..                              ...        ...             ...
# 74  counterfactually-augmented-data  sentiment        combined
# 75  counterfactually-augmented-data  sentiment        combined
# 76  counterfactually-augmented-data  sentiment        combined
# 77  counterfactually-augmented-data  sentiment        combined
# 78  counterfactually-augmented-data  sentiment        combined
#
#      #training instances       test split    #test instances  \
# 0                   1707         cad_orig                488
# 1                   1707          cad_cfs                488
# ...

# %%
df['acc_rounded'] = df[' accuracy'].apply(lambda x: np.round(x, 4))
df.head(25)
# Out:
#                         data origin  task name      training split  \
# 0   counterfactually-augmented-data  sentiment                orig
# 1   counterfactually-augmented-data  sentiment                orig
# 2   counterfactually-augmented-data  sentiment                orig
# 3   counterfactually-augmented-data  sentiment                orig
# 4   counterfactually-augmented-data  sentiment                 new
# 5   counterfactually-augmented-data  sentiment                 new
# 6   counterfactually-augmented-data  sentiment                 new
# 7   counterfactually-augmented-data  sentiment                 new
# 8   counterfactually-augmented-data  sentiment            combined
# 9   counterfactually-augmented-data  sentiment            combined
# 10  counterfactually-augmented-data  sentiment            combined
# 11  counterfactually-augmented-data  sentiment            combined
# 12  counterfactually-augmented-data        nli            original
# ...

# %%
df.to_csv('../results_rounded.csv', index=False)
